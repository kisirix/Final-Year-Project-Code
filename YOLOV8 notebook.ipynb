# %%
# !nvidia-smi
# Out:
# Tue Jun 27 09:05:36 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.123 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.3/78.2 GB disk)

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="nbN40uzNBt2NzQu5wgyZ")
project = rf.workspace("maize-specific").project("maize-leaf-diseases")
dataset = project.version(1).download("yolov8")
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.123, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to maize-leaf-diseases-1 in yolov8:: 100%|██████████| 20012/20012 [00:06<00:00, 2892.37it/s]

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# Use the model
model.train(data="/content/datasets/maize-leaf-diseases-1/data.yaml",epochs=10,imgsz=1024)  # train the model
# Out:
# Ultralytics YOLOv8.0.123 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.0.123 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients
# val: Scanning /content/datasets/maize-leaf-diseases-1/valid/labels.cache... 2000 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2000/2000 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 125/125 [00:48<00:00,  2.56it/s]
#                    all       2000       2000      0.993      0.993      0.994      0.752
#                    MLB       2000       1000      0.988      0.996      0.993      0.755
#                    MSV       2000       1000      0.999       0.99      0.995       0.75
# Speed: 1.2ms preprocess, 9.8ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to runs/detect/val

# %%
path = model.export(format="onnx")
# Out:
# Ultralytics YOLOv8.0.123 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# PyTorch: starting from runs/detect/train2/weights/best.pt with input shape (1, 3, 1024, 1024) BCHW and output shape(s) (1, 6, 21504) (6.0 MB)
# requirements: Ultralytics requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 135.1 MB/s eta 0:00:00
# ...
#
# requirements: 1 package updated per ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.14.0 opset 17...
# ONNX: export success ✅ 9.5s, saved as runs/detect/train2/weights/best.onnx (11.9 MB)
#
# Export complete (10.4s)
# Results saved to /content/datasets/runs/detect/train2/weights
# Predict:         yolo predict task=detect model=runs/detect/train2/weights/best.onnx imgsz=1024
# ...

# %%
pathe = model.export(format="tflite")
# Out:
# Ultralytics YOLOv8.0.123 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# PyTorch: starting from runs/detect/train2/weights/best.pt with input shape (1, 3, 1024, 1024) BCHW and output shape(s) (1, 6, 21504) (6.0 MB)
# requirements: Ultralytics requirements "onnx2tf>=1.7.7" "sng4onnx>=1.0.1" "onnxsim>=0.4.17" "onnx_graphsurgeon>=0.3.26" "tflite_support" "onnxruntime-gpu" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://pypi.ngc.nvidia.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 368.1/368.1 kB 25.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 59.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 203.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.3/390.3 kB 178.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
